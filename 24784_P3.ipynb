# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
! git clone https://github.com/LiousYao/24784-P3.git
# Out:
# Cloning into '24784-P3'...
# remote: Enumerating objects: 316, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 316 (delta 0), reused 0 (delta 0), pack-reused 310
# Receiving objects: 100% (316/316), 43.21 MiB | 20.77 MiB/s, done.
# Resolving deltas: 100% (51/51), done.

# %%
cd 24784-P3/24784P3
# Out:
# /content/24784-P3/24784P3

# %%
pip install -e .
# Out:
# Obtaining file:///content/24784-P3/24784P3
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: fsrl
#     Found existing installation: fsrl 0.1.0
#     Uninstalling fsrl-0.1.0:
#       Successfully uninstalled fsrl-0.1.0
#   Running setup.py develop for fsrl
# ...

# %%
cd ../Bullet-Safety-Gym
# Out:
# /content/24784-P3/Bullet-Safety-Gym

# %%
! pip install -e .
# Out:
# Obtaining file:///content/24784-P3/Bullet-Safety-Gym
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: bullet-safety-gym
#     Found existing installation: bullet-safety-gym 1.4.0
#     Uninstalling bullet-safety-gym-1.4.0:
#       Successfully uninstalled bullet-safety-gym-1.4.0
#   Running setup.py develop for bullet-safety-gym
# ...

# %%
cd ../24784P3
# Out:
# /content/24784-P3/24784P3

# %% [markdown]
# Train the PPO-Lag method in the Car-Circle env. train with 3 different random seeds. We utilize the wandb logger to store training stats.

# %%
! python train_ppol_agent.py --seed 10
# Out:
# safety_gymnasium is not found.
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:121: DeprecationWarning: pkg_resources is deprecated as an API
#   warnings.warn("pkg_resources is deprecated as an API", DeprecationWarning)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# ...
